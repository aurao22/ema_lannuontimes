# %%
import pandas as pd
from news_paper_dao import NewsPaperDao
from IPython.core.display import HTML
from os import getcwd
from news_paper_nlp_pre_processing import *
from nltk.corpus import stopwords
import nltk

# %%
# Récupère le répertoire du programme
curent_path = getcwd()+ "\\"
if "ema_lannuontimes" not in curent_path:
    curent_path += "PROJETS\\ema_lannuontimes\\"
print(curent_path)
# Out:
# c:\Users\User\WORK\workspace-ia\PROJETS\ema_lannuontimes\

# %% [markdown]
# <div style="display: flex; background-color: Blue; padding: 15px;" >
#
# ## 1.Exploration des données:
# </div>

# %%
verbose = 1

dao = NewsPaperDao(nom_bdd=curent_path+"em_bdd.db")
assert dao.test_connexion()

df_articles = dao.get_articles(verbose=0)
print(df_articles.shape)
# Out:
# La version de SQLite est:  [('3.35.5',)]
# (1840, 7)

# %%
color_by_journal = {"Le Trégor":"green","ActuGaming":"orange", "Elle":"pink", "30 M. d\\'amis":"blue"}
journaux = df_articles["journal"].unique()

# %%
print(df_articles.shape)
print(df_articles.columns)
display(HTML(df_articles.head().to_html()))
# Out:
# (1840, 7)
# Index(['titre', 'date_parution', 'journal', 'auteur', 'tags', 'texte', 'url'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>titre</th>
#       <th>date_parution</th>
#       <th>journal</th>
#       <th>auteur</th>
#       <th>tags</th>
#       <th>texte</th>
#       <th>url</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Lannion. Un cycliste renversé par une voiture en centre-ville</td>
#       <td>10 Mar 22 à 17:05</td>
#       <td>Le Trégor</td>
#       <td>Christophe Ganne</td>
#       <td>faits-divers</td>
#       <td>Jeudi 10 mars à 16 h 30, au rond point de la Poste à Lannion, en plein centre-ville, sur les quais, un cycliste a été renversé par une voiture. Légèrement blessé Le jeune cycliste, âgé de seize ans, a été légèrement blessé. Pompiers et policiers se sont rapidement rendus sur place. Le jeune homme a été pris en charge par les pompiers et transporté au centre hospitalier de Lannion.</td>
#       <td>https://actu.fr/bretagne/lannion_22113/lannion-un-cycliste-renverse-par-une-voiture-en-centre-ville_49325798.html</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Perros-Guirec. Panne électrique : la mairie invite les citoyens à économiser l\'énergie</td>
#       <td>8 Mar 22 à 10:33</td>
#       <td>Le Trégor</td>
#       <td>Christophe Ganne</td>
#       <td>societe</td>
#       <td>Suite à la panne d’électricité géante sur la côte de Granit rose,  ce week-end, de nombreuses coupures sont encore attendues jour et nuit. Les difficultés de réparation du poste de Saint-Quay-Perros vont encore durer un moment. Pas d’éclairage public Pour faire face, la mairie de Perros-Guirec va dès ce mardi soir 8 mars couper l’éclairage public. Nous avons 80 postes de répartition de l’éclairage public que nous allons couper, peut-être pas tout ce soir, mais dans les jours suivants. C’est une mesure d’économie pour ne pas trop tirer sur les installations précaires mises en place en attendant la réparation définitive. Economiser l’électricité Cette mesure publique s’accompagne aussi d’encouragements envers la population. Nous allons demander aux Perrosiens d’être vigilants sur leur consommation électrique le temps des réparations. Les élus confirment aussi les difficultés d’approvisionnement en gasoil des 124 groupes électrogènes installés dans les différentes communes de la côte de Granit rose. Les activités nautiques interdites Autre conséquence, les difficultés de fonctionnement des stations d’épuration. Les postes de relevage et de traitement ne fonctionnent pas normalement. La ville craint des débordements qui pourraient atteindre les plages. « Ce n’est pas encore le cas mais il y a des risques », explique Erven Léon. C’est pourquoi la mairie de Perros-Guirec a pris un arrêté interdisant les baignades et les activités nautiques sur les plages de Trestraou, Trestrignel et Saint-Guirec le temps d’un retour à la normale.</td>
#       <td>https://actu.fr/bretagne/perros-guirec_22168/perros-guirec-panne-electrique-la-mairie-invite-les-citoyens-a-economiser-lenergie_49242304.html</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Louannec. Un gang de l\'Est avait pillé le distributeur de billets : 5 interpellations</td>
#       <td>11 Mar 22 à 20:08</td>
#       <td>Le Trégor</td>
#       <td>Christophe Ganne</td>
#       <td>faits-divers</td>
#       <td>Les gendarmes de Perros-Guirec, Lannion, Rennes, Toulouse et le groupe de cybercriminalité de la gendarmerie ont pu interpeller les membres d’un groupe qui piratait les distributeurs il y a quelques jours. Liés à la criminalité Les membres de ce groupe sont liés à la criminalité organisée des pays de l’Est. Ils avaient dérobé 50 000 euros à Louannec. 50 000 euros à Louannec Les faits remontent à la nuit du 9 au 10 novembre 2021. A l’agence postale de Louannec, les individus percent le distributeur automatique afin de le pirater en se connectant dessus à l’aide d’un ordinateur. Une pratique connue appelée Jackpotting Le groupe repart avec 50 000 euros. Les gendarmes de Perros-Guirec et Lannion, appuyés par ceux de Rennes, mènent l’enquête. Des points communs Parallèlement, à Auch et Toulouse, des faits similaires sont relevés. Les enquêteurs mettent en commun leurs recherches et y trouvent des points communs. Le 3 février dernier, dans le sud ouest, les gendarmes de Toulouse ont interpellé 5 individus. 22 piratages pour 300 000 euros Ils ont reconnu avoir piraté 22 distributeurs de billets dans toute la France pour un montant total de 300 000 euros dont 50 000 euros à Louannec. C’est une opération énorme qui a été montée et une organisation qui a été démantelée. L’enquête se poursuit toutefois pour d’autres faits. Certains des membres du groupe sont actuellement incarcérés.</td>
#       <td>https://actu.fr/bretagne/louannec_22134/louannec-un-gang-de-lest-avait-pille-le-distributeur-de-billets-5-interpellations_49364830.html</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Lannion. Une conférence et une expo sur l’hydrogène</td>
#       <td>9 Mar 22 à 12:25</td>
#       <td>Le Trégor</td>
#       <td>Rédaction Lannion</td>
#       <td>Actualité</td>
#       <td>L’association ArmorScience propose à l’IUT de Lannion une exposition et une conférence sur l’hydrogène : « Hydrogène, vers un avenir décarboné ? » Le mercredi 9 mars à 18 h 30 à l’amphi 2 aura lieu la conférence qui permettra d’inaugurer l’exposition sur ce même thème. La conférence sera présentée par Francis Nativel, d’ArmorScience, et Loïc Perrin, d’H2X Ecosystems. Transition énergétique L’hydrogène est le plus léger des gaz. Il s’inscrit dans la panoplie des solutions mises en œuvre par de nombreux pays dans le cadre des plans de transition énergétique destinés à limiter l’impact des activités humaines sur le climat. « Utilisé essentiellement dans le raffinage du pétrole et dans la chimie, l’hydrogène pourrait contribuer à décarboner les transports et certains secteurs industriels parce qu’il n’émet aucun gaz à effet de serre au moment de son utilisation. » Nous souhaitons amener au débat sur l’hydrogène, une information neutre, indépendante et accessible à un large public. Pendant deux semaines, du 9 au 25 mars, il sera possible de consulter en accès libre l’exposition qui se tiendra dans le couloir de la cafétéria de l’établissement. ArmorScience est une association ayant pour objectif la diffusion de la culture scientifique. Elle  souhaite vulgariser la culture scientifique auprès du grand public, mais « vise plus particulièrement les étudiants et les adhérents de l’association ». Lien d’inscription pour participer à la conférence : https://my.weezevent.com/conference-armorscience La conférence sera diffusée en direct sur https://us02web.zoom.us/j/89164878947/</td>
#       <td>https://actu.fr/bretagne/lannion_22113/lannion-une-conference-et-une-expo-sur-lhydrogene_49223963.html</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Autour de Perros. Panne : des groupes électrogènes éteints dès ce vendredi</td>
#       <td>11 Mar 22 à 12:21</td>
#       <td>Le Trégor</td>
#       <td>Rédaction Lannion</td>
#       <td>societe</td>
#       <td>Le village vacances de la CCAS, à Trébeurden, n’a pas fermé ses portes dimanche 6 mars comme prévu. Une soixantaine de salariés d’Enedis, mobilisés sur le vaste chantier de la panne électrique du 5 mars, a été accueillie. Une bonne centaine a été logée dans les hôtels alentour. Jeudi 10 mars en soirée, ils n’étaient plus qu’une dizaine de Bretons à la CCAS, présents pour 4 jours avant que d’autres ne prennent le relais. Soutien aux collègues trégorrois Beaucoup des techniciens présents depuis dimanche sont des volontaires de la Force d’intervention rapide électricité (Fire). Quand j’ai vu le message dimanche matin sur WhatsApp, j’ai appelé mon chef et je suis parti. La Rennaise Virginie est assistante et sur cette panne, elle gère les approvisionnements en fuel (100 000 litres par jour). Aucun n’a hésité à venir soutenir ses collègues trégorrois pour amoindrir les conséquences sur la population. « On a de bons contacts avec les gens. » Des habitants manifestent leur

# %%
import matplotlib.pyplot as plt

# %%
figure, axe = color_graph_background(1, 1)

bins = len(journaux)
for journal in journaux:
    df_articles[df_articles["journal"]==journal].journal.hist(ax=axe, color=color_by_journal.get(journal, "gray"), bins=bins)

figure.set_size_inches(15, 5, forward=True)
axe.set_ylabel("Nombre d'articles")
plt.title("Nombre d'articles par journal")
plt.xticks(rotation=45, ha="right")
plt.show()

# %%
df_articles = df_word_tokenize(df_articles, text_col_name='texte', token_col_name="mots_origine", verbose=verbose)

# %%
df_articles["nb_mots_origine"] = df_articles['texte'].apply(lambda x: word_count_func(x))

# %%
group = df_articles.groupby(["journal"], as_index=True).agg({'nb_mots_origine':['mean']})
group = group.reset_index()
group
# Out:
#          journal nb_mots_origine
#                             mean
# 0  30 M. d\'amis     1315.494340
# 1     ActuGaming      321.342000
# 2           Elle      387.481308
# 3      Le Trégor      301.238095

# %%
df_articles.columns
# Out:
# Index(['titre', 'date_parution', 'journal', 'auteur', 'tags', 'texte', 'url',
#        'mots_origine', 'nb_mots_origine'],
#       dtype='object')

# %%
list_tuple = [(i, i+299) for i in range (600, 3300, 300)]
list_tuple.insert(0, (200, 299))
list_tuple.insert(0, (100, 199))
list_tuple.insert(0, (0, 99))
list_tuple.append((3300, 100000))
bins = pd.IntervalIndex.from_tuples(list_tuple)
df_articles["tranche_nb_origin"] = pd.cut(df_articles['nb_mots_origine'], bins)
df_articles.head()
# Out:
#                                                titre      date_parution  \
# 0  Lannion. Un cycliste renversé par une voiture ...  10 Mar 22 à 17:05
# 1  Perros-Guirec. Panne électrique : la mairie in...   8 Mar 22 à 10:33
# 2  Louannec. Un gang de l\'Est avait pillé le dis...  11 Mar 22 à 20:08
# 3  Lannion. Une conférence et une expo sur l’hydr...   9 Mar 22 à 12:25
# 4  Autour de Perros. Panne : des groupes électrog...  11 Mar 22 à 12:21
#
#      journal             auteur          tags  \
# 0  Le Trégor   Christophe Ganne  faits-divers
# 1  Le Trégor   Christophe Ganne       societe
# 2  Le Trégor   Christophe Ganne  faits-divers
# 3  Le Trégor  Rédaction Lannion     Actualité
# 4  Le Trégor  Rédaction Lannion       societe
#
#                                                texte  \
# 0  Jeudi 10 mars à 16 h 30, au rond point de la P...
# 1  Suite à la panne d’électricité géante sur la c...
# 2  Les gendarmes de Perros-Guirec, Lannion, Renne...
# 3  L’association ArmorScience propose à l’IUT de ...
# 4  Le village vacances de la CCAS, à Trébeurden, ...
#
#                                                  url  \
# 0  https://actu.fr/bretagne/lannion_22113/lannion...
# 1  https://actu.fr/bretagne/perros-guirec_22168/p...
# 2  https://actu.fr/bretagne/louannec_22134/louann...
# 3  https://actu.fr/bretagne/lannion_22113/lannion...
# 4  https://actu.fr/bretagne/trebeurden_22343/auto...
#
#                                         mots_origine  nb_mots_origine  \
# 0  [jeudi, 10, mars, à, 16, h, 30, au, rond, poin...               69
# 1  [suite, à, la, panne, d, électricité, géante, ...              233
# 2  [les, gendarmes, de, perros, guirec, lannion, ...              228
# 3  [l, association, armorscience, propose, à, l, ...              236
# 4  [le, village, vacances, de, la, ccas, à, trébe...              422
#
#   tranche_nb_origin
# 0       (0.0, 99.0]
# 1    (200.0, 299.0]
# 2    (200.0, 299.0]
# 3    (200.0, 299.0]
# 4               NaN

# %%
group_nb_mots_art = df_articles.groupby(["journal", "tranche_nb_origin" ])["titre"].count().unstack("journal").fillna(0)
group_nb_mots_art.head()
# Out:
# journal            30 M. d\'amis  ActuGaming  Elle  Le Trégor
# tranche_nb_origin
# (0, 99]                        0          14     0          7
# (100, 199]                     0          96     3         49
# (200, 299]                     5         231   129         53
# (600, 899]                    83          11     6         13
# (900, 1199]                   97          11    10          0

# %%
from matplotlib.colors import ListedColormap

# %%
figure, axe = color_graph_background(1,1)

# On applique les mêmes couleurs que dans les autres graphes
my_cmap = ListedColormap(['blue', 'orange', 'pink', 'green'])

# Affichage d'articles par journal
group_nb_mots_art.plot(kind='bar', ax=axe, cmap=my_cmap)
axe.set_ylabel("Nombre d'articles")
axe.grid(axis='y')

figure.set_size_inches(16, 8, forward=True)
figure.suptitle("Nombre d'articles par tranche de mots", fontsize=16)
plt.xticks(rotation=45, ha="right")
plt.show()

# %%
df_articles.describe()
# Out:
#        nb_mots_origine
# count      1840.000000
# mean        628.942391
# std         675.468248
# min          60.000000
# 25%         275.000000
# 50%         357.000000
# 75%         678.250000
# max        6930.000000

# %%
df_articles.head()
# Out:
#                                                titre      date_parution  \
# 0  Lannion. Un cycliste renversé par une voiture ...  10 Mar 22 à 17:05
# 1  Perros-Guirec. Panne électrique : la mairie in...   8 Mar 22 à 10:33
# 2  Louannec. Un gang de l\'Est avait pillé le dis...  11 Mar 22 à 20:08
# 3  Lannion. Une conférence et une expo sur l’hydr...   9 Mar 22 à 12:25
# 4  Autour de Perros. Panne : des groupes électrog...  11 Mar 22 à 12:21
#
#      journal             auteur          tags  \
# 0  Le Trégor   Christophe Ganne  faits-divers
# 1  Le Trégor   Christophe Ganne       societe
# 2  Le Trégor   Christophe Ganne  faits-divers
# 3  Le Trégor  Rédaction Lannion     Actualité
# 4  Le Trégor  Rédaction Lannion       societe
#
#                                                texte  \
# 0  Jeudi 10 mars à 16 h 30, au rond point de la P...
# 1  Suite à la panne d’électricité géante sur la c...
# 2  Les gendarmes de Perros-Guirec, Lannion, Renne...
# 3  L’association ArmorScience propose à l’IUT de ...
# 4  Le village vacances de la CCAS, à Trébeurden, ...
#
#                                                  url  \
# 0  https://actu.fr/bretagne/lannion_22113/lannion...
# 1  https://actu.fr/bretagne/perros-guirec_22168/p...
# 2  https://actu.fr/bretagne/louannec_22134/louann...
# 3  https://actu.fr/bretagne/lannion_22113/lannion...
# 4  https://actu.fr/bretagne/trebeurden_22343/auto...
#
#                                         mots_origine  nb_mots_origine  \
# 0  [jeudi, 10, mars, à, 16, h, 30, au, rond, poin...               69
# 1  [suite, à, la, panne, d, électricité, géante, ...              233
# 2  [les, gendarmes, de, perros, guirec, lannion, ...              228
# 3  [l, association, armorscience, propose, à, l, ...              236
# 4  [le, village, vacances, de, la, ccas, à, trébe...              422
#
#   tranche_nb_origin
# 0       (0.0, 99.0]
# 1    (200.0, 299.0]
# 2    (200.0, 299.0]
# 3    (200.0, 299.0]
# 4               NaN

# %%
df_articles.columns
# Out:
# Index(['titre', 'date_parution', 'journal', 'auteur', 'tags', 'texte', 'url',
#        'mots_origine', 'nb_mots_origine', 'tranche_nb_origin'],
#       dtype='object')

# %% [markdown]
# <div style="display: flex; background-color: Blue; padding: 15px;" >
#
# ## 3.NLP Preprocessing
# </div>

# %%
personnal_stop_word = ["tout", "tous", "cette", "bien", "comme", "encore", "autre", "bien", "tres", "alors", "plus", "aussi", "si", "donc", "p", "h", "etre"]
if personnal_stop_word is None:
    personnal_stop_word = stopwords.words("french")
else :
    personnal_stop_word.extend(stopwords.words("french"))
len(personnal_stop_word)
# Out:
# 174

# %%
def nlp_pre_process(input, sw=None, verbose=0):
    res = []
    res = tokenize(input)
    res = remove_stopwords_func(res, sw=sw)
    res = normalize_accented_chars(res)
    res = remove_irr_char_func(res)        
    res = remove_stopwords_func(res, sw=sw)
        
    res = list(filter(None, res))
    return res

# %%
df_articles["clean_words"] = df_articles['texte'].apply(lambda x: nlp_pre_process(x, sw=personnal_stop_word))
print(df_articles.columns)
display(HTML(df_articles.head().to_html()))
# Out:
# Index(['titre', 'date_parution', 'journal', 'auteur', 'tags', 'texte', 'url',
#        'mots_origine', 'nb_mots_origine', 'tranche_nb_origin', 'clean_words'],
#       dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>titre</th>
#       <th>date_parution</th>
#       <th>journal</th>
#       <th>auteur</th>
#       <th>tags</th>
#       <th>texte</th>
#       <th>url</th>
#       <th>mots_origine</th>
#       <th>nb_mots_origine</th>
#       <th>tranche_nb_origin</th>
#       <th>clean_words</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Lannion. Un cycliste renversé par une voiture en centre-ville</td>
#       <td>10 Mar 22 à 17:05</td>
#       <td>Le Trégor</td>
#       <td>Christophe Ganne</td>
#       <td>faits-divers</td>
#       <td>Jeudi 10 mars à 16 h 30, au rond point de la Poste à Lannion, en plein centre-ville, sur les quais, un cycliste a été renversé par une voiture. Légèrement blessé Le jeune cycliste, âgé de seize ans, a été légèrement blessé. Pompiers et policiers se sont rapidement rendus sur place. Le jeune homme a été pris en charge par les pompiers et transporté au centre hospitalier de Lannion.</td>
#       <td>https://actu.fr/bretagne/lannion_22113/lannion-un-cycliste-renverse-par-une-voiture-en-centre-ville_49325798.html</td>
#       <td>[jeudi, 10, mars, à, 16, h, 30, au, rond, point, de, la, poste, à, lannion, en, plein, centre, ville, sur, les, quais, un, cycliste, a, été, renversé, par, une, voiture, légèrement, blessé, le, jeune, cycliste, âgé, de, seize, ans, a, été, légèrement, blessé, pompiers, et, policiers, se, sont, rapidement, rendus, sur, place, le, jeune, homme, a, été, pris, en, charge, par, les, pompiers, et, transporté, au, centre, hospitalier, de, lannion]</td>
#       <td>69</td>
#       <td>(0.0, 99.0]</td>
#       <td>[jeudi, mars, rond, point, poste, lannion, plein, centre, ville, quais, cycliste, a, renverse, voiture, legerement, blesse, jeune, cycliste, age, seize, ans, a, legerement, blesse, pompiers, policiers, rapidement, rendus, place, jeune, homme, a, pris, charge, pompiers, transporte, centre, hospitalier, lannion]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Perros-Guirec. Panne électrique : la mairie invite les citoyens à économiser l\'énergie</td>
#       <td>8 Mar 22 à 10:33</td>
#       <td>Le Trégor</td>
#       <td>Christophe Ganne</td>
#       <td>societe</td>
#       <td>Suite à la panne d’électricité géante sur la côte de Granit rose,  ce week-end, de nombreuses coupures sont encore attendues jour et nuit. Les difficultés de réparation du poste de Saint-Quay-Perros vont encore durer un moment. Pas d’éclairage public Pour faire face, la mairie de Perros-Guirec va dès ce mardi soir 8 mars couper l’éclairage public. Nous avons 80 postes de répartition de l’éclairage public que nous allons couper, peut-être pas tout ce soir, mais dans les jours suivants. C’est une mesure d’économie pour ne pas trop tirer sur les installations précaires mises en place en attendant la réparation définitive. Economiser l’électricité Cette mesure publique s’accompagne aussi d’encouragements envers la population. Nous allons demander aux Perrosiens d’être vigilants sur leur consommation électrique le temps des réparations. Les élus confirment aussi les difficultés d’approvisionnement en gasoil des 124 groupes électrogènes installés dans les différentes communes de la côte de Granit rose. Les activités nautiques interdites Autre conséquence, les difficultés de fonctionnement des stations d’épuration. Les postes de relevage et de traitement ne fonctionnent pas normalement. La ville craint des débordements qui pourraient atteindre les plages. « Ce n’est pas encore le cas mais il y a des risques », explique Erven Léon. C’est pourquoi la mairie de Perros-Guirec a pris un arrêté interdisant les baignades et les activités nautiques sur les plages de Trestraou, Trestrignel et Saint-Guirec le temps d’un retour à la normale.</td>
#       <td>https://actu.fr/bretagne/perros-guirec_22168/perros-guirec-panne-electrique-la-mairie-invite-les-citoyens-a-economiser-lenergie_49242304.html</td>
#       <td>[suite, à, la, panne, d, électricité, géante, sur, la, côte, de, granit, rose, ce, week, end, de, nombreuses, coupures, sont, encore, attendues, jour, et, nuit, les, difficultés, de, réparation, du, poste, de, saint, quay, perros, vont, encore, durer, un, moment, pas, d, éclairage, public, pour, faire, face, la, mairie, de, perros, guirec, va, dès, ce, mardi, soir, 8, mars, couper, l, éclairage, public, nous, avons, 80, postes, de, répartition, de, l, éclairage, public, que, nous, allons, couper, peut, être, pas, tout, ce, soir, mais, dans, les, jours, suivants, c, est, une, mesure, d, économie, pour, ne, pas, trop, tirer, sur, ...]</td>
#       <td>233</td>
#       <td>(200.0, 299.0]</td>
#       <td>[suite, panne, electricite, geante, cote, granit, rose, week, end, nombreuses, coupures, attendues, jour, nuit, difficultes, reparation, poste, saint, quay, perros, vont, durer, moment, eclairage, public, faire, face, mairie, perros, guirec, va, mardi, soir, mars, couper, eclairage, public, postes, repartition, eclairage, public, allons, couper, peut, soir, jours, suivants, mesure, economie, trop, tirer, installations, precaires, mises, place, attendant, reparation, definitive, economiser, electricite, mesure, publique, accompagne, encouragements, envers, population, allons, demander, perrosiens, vigilants, consommation, electrique, temps, reparations, elus, confirment, difficultes, approvisionnement, gasoil, groupes, electrogenes, installes, differentes, communes, cote, granit, rose, activites, nautiques, interdites, consequence, difficultes, fonctionnement, stations, epuration, postes, relevage, traitement, fonctionnent, normalement, ...]</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Louannec. Un gang de l\'Est avait pillé le distributeur de billets : 5 interpellations</td>
#       <td>11 Mar 22 à 20:08</td>
#       <td>Le Trégor</td>
#       <td>Christophe Ganne</td>
#       <td>faits-divers</td>
#       <td>Les gendarmes de Perros-Guirec, Lannion, Rennes, Toulouse et le groupe de cybercriminalité de la gendarmerie ont pu interpeller les membres d’un groupe qui piratait les distributeurs il y a quelques jours. Liés à la criminalité Les membres de ce groupe sont liés à la criminalité organisée des pays de l’Est. Ils avaient dérobé 50 000 euros à Louannec. 50 000 euros à Louannec Les faits remontent à la nuit du 9 au 10 novembre 2021. A l’agence postale de Louannec, les individus percent le distributeur automatique afin de le pirater en se connectant dessus à l’aide d’un ordinateur. Une pratique connue appelée Jackpotting Le groupe repart avec 50 000 euros. Les gendarmes de Perros-Guirec et Lannion, appuyés par ceux de Rennes, mènent l’enquête. Des points communs Parallèlement, à Auch et Toulouse, des faits similaires sont relevés. Les enquêteurs mettent en commun leurs recherches et y trouvent des points communs. Le 3 février dernier, dans le sud ouest, les gendarmes de Toulouse ont interpellé 5 individus. 22 piratages pour 300 000 euros Ils ont reconnu avoir piraté 22 distributeurs de billets dans toute la France pour un montant total de 300 000 euros dont 50 000 euros à Louannec. C’est une opération énorme qui a été montée et une organisation qui a été démantelée. L’enquête se poursuit toutefois pour d’autres faits. Certains des membres du groupe sont actuellement incarcérés.</td>
#       <td>https://actu.fr/bretagne/louannec_22134/louannec-un-gang-de-lest-avait-pille-le-distributeur-de-billets-5-interpellations_49364830.html</td>
#       <td>[les, gendarmes, de, perros, guirec, lannion, rennes, toulouse, et, le, groupe, de, cybercriminalité, de, la, gendarmerie, ont, pu, interpeller, les, membres, d, un, groupe, qui, piratait, les, distributeurs, il, y, a, quelques, jours, liés, à, la, criminalité, les, membres, de, ce, groupe, sont, liés, à, la, criminalité, organisée, des, pays, de, l, est, ils, avaient, dérobé, 50, 000, euros, à, louannec, 50, 000, euros, à, louannec, les, faits, remontent, à, la, nuit, du, 9, au, 10, novembre, 2021, a, l, agence, postale, de, louanne

# %% [markdown]
# <div style="display: flex; background-color: Green; padding: 7px;" >
#
# ### 3.1.Analyse nb mots
# </div>

# %%
df_articles["nb_mots_clean"] = df_articles['clean_words'].apply(lambda x: word_count_func(x))

# %%
df_articles["freq_name"] = df_articles["clean_words"].apply(lambda x: nltk.FreqDist(x))
df_articles["freq_unique_words"] = df_articles["freq_name"].apply(lambda x: len(x.keys()))

# %%
df_articles = df_articles.sort_values(by=["freq_unique_words"], ascending=False)

# %%
df_articles.head()
# Out:
#                                                   titre  \
# 913             Tous les MMO à venir en 2022 et au-delà
# 833   Assassin’s Creed Valhalla : L’Aube du Ragnarök...
# 1765         Charlène de Monaco : du conte à la réalité
# 1112  Pourquoi on aimerait voir un reboot de Darksta...
# 694   Pourquoi on aimerait un retour de la licence d...
#
#                  date_parution     journal           auteur    tags  \
# 913    28 janvier 2022 à 16:40  ActuGaming           Jordan  gaming
# 833        9 mars 2022 à 12:01  ActuGaming         FloRizzo  gaming
# 1765  15 décembre 2021 à 11h35        Elle  Dorothée Werner  People
# 1112    6 février 2022 à 11:00  ActuGaming    Neomantis Dee  gaming
# 694       20 mars 2022 à 11:00  ActuGaming  Nathan Champion  gaming
#
#                                                   texte  \
# 913   Mine de rien, l’année 2021 a été assez chargée...
# 833   Depuis le lancement de la nouvelle trilogie my...
# 1765  Il était une fois une princesse enfermée dans ...
# 1112  Fort des succès critiques et commerciaux de Dr...
# 694   Certains jeux vous marquent à vie, et pas touj...
#
#                                                     url  \
# 913   https://www.actugaming.net/sorties-mmo-2022-46...
# 833   https://www.actugaming.net/assassins-creed-val...
# 1765  https://www.elle.fr/People/La-vie-des-people/N...
# 1112  https://www.actugaming.net/pourquoi-on-aimerai...
# 694   https://www.actugaming.net/retour-de-blob-chro...
#
#                                            mots_origine  nb_mots_origine  \
# 913   [mine, de, rien, l, année, 2021, a, été, assez...             4229
# 833   [depuis, le, lancement, de, la, nouvelle, tril...             2201
# 1765  [il, était, une, fois, une, princesse, enfermé...             1916
# 1112  [fort, des, succès, critiques, et, commerciaux...             2062
# 694   [certains, jeux, vous, marquent, à, vie, et, p...             2212
#
#      tranche_nb_origin                                        clean_words  \
# 913     (3300, 100000]  [mine, rien, annee, a, assez, chargee, sorties...
# 833       (2100, 2399]  [depuis, lancement, nouvelle, trilogie, mythol...
# 1765      (1800, 2099]  [fois, princesse, enfermee, etrange, melancoli...
# 1112      (1800, 2099]  [fort, succes, critiques, commerciaux, dragon,...
# 694       (2100, 2399]  [certains, jeux, marquent, vie, toujours, rais...
#
#       nb_mots_clean                                          freq_name  \
# 913            2359  {'mine': 1, 'rien': 4, 'annee': 22, 'a': 41, '...
# 833            1202  {'depuis': 5, 'lancement': 1, 'nouvelle': 3, '...
# 1765           1026  {'fois': 6, 'princesse': 8, 'enfermee': 1, 'et...
# 1112           1119  {'fort': 1, 'succes': 2, 'critiques': 1, 'comm...
# 694            1151  {'certains': 2, 'jeux': 9, 'marquent': 1, 'vie...
#
#       freq_unique_words
# 913                1066
# 833                 791
# 1765                748
# 1112                724
# 694                 713

# %%
figure, axe = color_graph_background(1,1)

df_articles.plot(kind='bar', x='titre', y="nb_mots_clean", ax=axe, title='Nombre de mots par article')
df_articles.plot(y="freq_unique_words", x='titre', kind="bar", ax=axe, color="red")
figure.set_size_inches(16, 8, forward=True)

plt.ylabel("Nombre de mots par article")
plt.xlabel("")
plt.xticks([])
# plt.xticks(rotation=45, ha="right")
plt.show()

# %%
figure, axes = color_graph_background(len(journaux),1)

y_ticks = [i for i in range(0, 1200, 200)]

i = 0
for journal in journaux:
    df_articles[df_articles["journal"]==journal].plot(y="freq_unique_words", x='titre', label=journal, kind="bar", ax=axes[i], color=color_by_journal.get(journal, "gray"))
    axes[i].set_yticks(y_ticks)
    axes[i].set_xticks([])
    i += 1

figure.set_size_inches(16, 8, forward=True)
plt.suptitle('Nombre de mots uniques par article par journal', fontsize=16)
plt.xlabel("Articles")
plt.xticks([])
plt.show()

# %% [markdown]
# <div style="display: flex; background-color: Green; padding: 7px;" >
#
# ### 3.2.Nuage de mots
# </div>

# %%
from wordcloud import WordCloud

# %% [markdown]
# <div style="display: flex; background-color: indigo;" >
#
# #### 3.2.1. SANS lemmatisation
# </div>

# %%
df_articles["texte_clean"] = [','.join(map(str, l)) for l in df_articles["clean_words"]]
df_articles["sentence_clean"] = [' '.join(map(str, l)) for l in df_articles["clean_words"]]
df_articles["texte_clean"]
# Out:
# 913     mine,rien,annee,a,assez,chargee,sorties,gros,m...
# 833     depuis,lancement,nouvelle,trilogie,mythologiqu...
# 1765    fois,princesse,enfermee,etrange,melancolie,pri...
# 1112    fort,succes,critiques,commerciaux,dragon,ball,...
# 694     certains,jeux,marquent,vie,toujours,raisons,fa...
#                               ...
# 77      incendie,declare,tot,jeudi,mars,maison,habitat...
# 993     longtemps,repousse,rainbow,six,extraction,fina...
# 779     certains,peut,connu,epoque,windjammers,classiq...
# 54      policiers,intervenir,nuit,jeudi,vendredi,mars,...
# 0       jeudi,mars,rond,point,poste,lannion,plein,cent...
# Name: texte_clean, Length: 1840, dtype: object

# %%
for journal in journaux:
    word_cloud(journal, df_articles)

# %% [markdown]
# <div style="display: flex; background-color: Blue; padding: 15px;" >
#
# ## 4.Entrainement d'un modèle de classification
# </div>

# %% [markdown]
# Questions :
# - Est-ce qu'on met en place l'approche td-idf ?
# - Est-ce qu'on fait la lemmatisation ?
# -

# %% [markdown]
# <div style="display: flex; background-color: Green; padding: 7px;" >
#
# ### 4.0.Préparer les données
# </div>

# %% [markdown]
# <div style="display: flex; background-color: indigo;" >
#
# #### 4.0.1. Encodage de la target
# </div>

# %%
from sklearn.preprocessing import LabelEncoder

# %%
random_state = 0

# %%
target_name = 'journal_code'
transformer_news_paper = LabelEncoder()
df_articles[target_name] = transformer_news_paper.fit_transform(df_articles["journal"])
#-- On positionne la colonne juste avant le nom du journal pour plus de lisibilité
cols = list(df_articles.columns)
cols.remove(target_name)
idx = cols.index('journal')
cols.insert(idx, target_name)
df_articles = df_articles[cols]
#--
df_articles
# Out:
#                                                   titre  \
# 913             Tous les MMO à venir en 2022 et au-delà
# 833   Assassin’s Creed Valhalla : L’Aube du Ragnarök...
# 1765         Charlène de Monaco : du conte à la réalité
# 1112  Pourquoi on aimerait voir un reboot de Darksta...
# 694   Pourquoi on aimerait un retour de la licence d...
# ...                                                 ...
# 77    Trélévern. La chaudière met le feu au sous sol...
# 993   Rainbow Six Extraction : Un bon jeu coop dans ...
# 779   Windjammers 2 : Que vaut le jeu de frisbee com...
# 54    Lannion. Cinq poneys en divagation route de Tr...
# 0     Lannion. Un cycliste renversé par une voiture ...
#
#                  date_parution  journal_code     journal             auteur  \
# 913    28 janvier 2022 à 16:40             1  ActuGaming             Jordan
# 833        9 mars 2022 à 12:01             1  ActuGaming           FloRizzo
# 1765  15 décembre 2021 à 11h35             2        Elle    Dorothée Werner
# 1112    6 février 2022 à 11:00             1  ActuGaming      Neomantis Dee
# 694       20 mars 2022 à 11:00             1  ActuGaming    Nathan Champion
# ...                        ...           ...         ...                ...
# 77            3 Mar 22 à 16:06             3   Le Trégor   Christophe Ganne
# 993    10 février 2022 à 11:36             1  ActuGaming             Julien
# 779     8 février 2022 à 17:17             1  ActuGaming             Julien
# 54            4 Mar 22 à 18:39             3   Le Trégor  Rédaction Lannion
# 0            10 Mar 22 à 17:05             3   Le Trégor   Christophe Ganne
#
#               tags                                              texte  \
# 913         gaming  Mine de rien, l’année 2021 a été assez chargée...
# 833         gaming  Depuis le lancement de la nouvelle trilogie my...
# 1765        People  Il était une fois une princesse enfermée dans ...
# 1112        gaming  Fort des succès critiques et commerciaux de Dr...
# 694         gaming  Certains jeux vous marquent à vie, et pas touj...
# ...            ...                                                ...
# 77    faits-divers  L’incendie s’est déclaré tôt ce jeudi 3 mars d...
# 993         gaming  Longtemps repoussé, Rainbow Six Extraction est...
# 779         gaming  Certains ne l’ont peut-être pas connu à l’époq...
# 54    faits-divers  Les policiers ont dû intervenir dans la nuit d...
# 0     faits-divers  Jeudi 10 mars à 16 h 30, au rond point de la P...
#
#                                                     url  \
# 913   https://www.actugaming.net/sorties-mmo-2022-46...
# 833   https://www.actugaming.net/assassins-creed-val...
# 1765  https://www.elle.fr/People/La-vie-des-people/N...
# 1112  https://www.actugaming.net/pourquoi-on-aimerai...
# 694   https://www.actugaming.net/retour-de-blob-chro...
# ...                                                 ...
# 77    https://actu.fr/bretagne/trelevern_22363/trele...
# 993   https://www.actugaming.net/rainbow-six-extract...
# 779   https://www.actugaming.net/windjammers-2-que-v...
# 54    https://actu.fr/bretagne/lannion_22113/lannion...
# 0     https://actu.fr/bretagne/lannion_22113/lannion...
#
#                                            mots_origine  nb_mots_origine  \
# 913   [mine, de, rien, l, année, 2021, a, été, assez...             4229
# 833   [depuis, le, lancement, de, la, nouvelle, tril...             2201
# 1765  [il, était, une, fois, une, princesse, enfermé...             1916
# 1112  [fort, des, succès, critiques, et, commerciaux...             2062
# 694   [certains, jeux, vous, marquent, à, vie, et, p...             2212
# ...                                                 ...              ...
# 77    [l, incendie, s, est, déclaré, tôt, ce, jeudi,...               71
# 993   [longtemps, repoussé, rainbow, six, extraction...               60
# 779   [certains, ne, l, ont, peut, être, pas, connu,...               71
# 54    [les, policiers, ont, dû, intervenir, dans, la...               74
# 0     [jeudi, 10, mars, à, 16, h, 30, au, rond, poin...               69
#
#      tranche_nb_origin                                        clean_words  \
# 913     (3300, 100000]  [mine, rien, annee, a, assez, chargee, sorties...
# 833       (2100, 2399]  [depuis, lancement, nouvelle, trilogie, mythol...
# 1765      (1800, 2099]  [fois, princesse, enfermee, etrange, melancoli...
# 1112      (1800, 2099]  [fort, succes, critiques, commerciaux, dragon,...
# 694       (2100, 2399]  [certains, jeux, marquent, vie, toujours, rais...
# ...                ...                                                ...
# 77             (0, 99]  [incendie, declare, tot, jeudi, mars, maison, ...
# 993            (0, 99]  [longtemps, repousse, rainbow, six, extraction...
# 779            (0, 99]  [certains, peut, connu, epoque, windjammers, c...
# 54             (0, 99]  [policiers, intervenir, nuit, jeudi, vendredi,...
# 0              (0, 99]  [jeudi, mars, rond, point, poste, lannion, ple...
#
#       nb_mots_clean                                          freq_name  \
# 913            2359  {'mine': 1, 'rien': 4, 'annee': 22, 'a': 41, '...
# 833            1202  {'depuis': 5, 'lancement': 1, 'nouvelle': 3, '...
# 1765           1026  {'fois': 6, 'princesse': 8, 'enfermee': 1, 'et...
# 1112           1119  {'fort': 1, 'succes': 2, 'critiques': 1, 'comm...
# 694            1151  {'certains': 2, 'jeux': 9, 'marquent': 1, 'vie...
# ...             ...                                                ...
# 77               41  {'incendie': 2, 'declare': 1, 'tot': 1, 'jeudi...
# 993              41  {'longtemps': 1, 'repousse': 1, 'rainbow': 3, ...
# 779              36  {'certains': 1, 'peut': 1, 'connu': 1, 'epoque...
# 54               38  {'policiers': 2, 'intervenir': 1, 'nuit': 1, '...
# 0                39  {'jeudi': 1, 'mars': 1, 'rond': 1, 'point': 1,...
#
#       freq_unique_words                                        texte_clean  \
# 913                1066  mine,rien,annee,a,assez,chargee,sorties,gros,m...
# 833                 791  depuis,lancement,nouvelle,trilogie,mythologiqu...
# 1765                748  fois,princesse,enfermee,etrange,melancolie,pri...
# 1112                724  fort,succes,critiques,commerciaux,dragon,ball,...
# 694                 713  certains,jeux,marquent,vie,toujours,raisons,fa...
# ...                 ...                                                ...
# 77                   36  incendie,declare,tot,jeudi,mars,maison,habitat...
# 993                  36  longtemps,repousse,rainbow,six,extraction,fina...
# 779                  35  certains,peut,connu,epoque,windjammers,classiq...
# 54                   34  policiers,intervenir,nuit,jeudi,vendredi,mars,...
# 0                    30  jeudi,mars,rond,point,poste,lannion,plein,cent...
#
#                                          sentence_clean
# 913   mine rien annee a assez chargee sorties gros m...
# 833   depuis lancement nouvelle trilogie mythologiqu...
# 1765  fois princesse enfermee etrange melancolie pri...
# 1112  fort succes critiques commerciaux dragon ball ...
# 694   certains jeux marquent vie toujours raisons fa...
# ...                                                 ...
# 77    incendie declare tot jeudi mars maison habitat...
# 993   longtemps repousse rainbow six extraction fina...
# 779   certains peut connu epoque windjammers classiq...
# 54    policiers intervenir nuit jeudi vendredi mars ...
# 0     jeudi mars rond point poste lannion plein cent...
#
# [1840 rows x 17 columns]

# %% [markdown]
# <div style="display: flex; background-color: Green; padding: 7px;" >
#
# ### 4.1.Essaie avec TF-IDF
# </div>

# %% [markdown]
# <div style="display: flex; background-color: indigo;" >
#
# #### 4.0.2. Calcul
# </div>

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
idf_full = df_articles.copy()

# %%
df_articles.columns
# Out:
# Index(['titre', 'date_parution', 'journal_code', 'journal', 'auteur', 'tags',
#        'texte', 'url', 'mots_origine', 'nb_mots_origine', 'tranche_nb_origin',
#        'clean_words', 'nb_mots_clean', 'freq_name', 'freq_unique_words',
#        'texte_clean', 'sentence_clean'],
#       dtype='object')

# %%
vectorizer_idf_big = TfidfVectorizer(analyzer="word",token_pattern=get_regex_tokens(), stop_words=personnal_stop_word, ngram_range = (1,1), max_features=400)
X = vectorizer_idf_big.fit_transform(idf_full['sentence_clean'])
idf_big_df = pd.DataFrame(X.toarray(), index=idf_full.index, columns=vectorizer_idf_big.get_feature_names_out())
# ajout du site web

# Réorganisation des colonnes pour la lecture
idf_full = pd.merge(idf_full, idf_big_df, left_index=True, right_index=True)
idf_full = idf_full.drop(["mots_origine", "url", "nb_mots_origine",'auteur', 'tags', 'nb_mots_clean','freq_name','freq_unique_words'], axis=1)
# --
idf_full.head()
# Out:
#                                                 titre_x  \
# 913             Tous les MMO à venir en 2022 et au-delà
# 833   Assassin’s Creed Valhalla : L’Aube du Ragnarök...
# 1765         Charlène de Monaco : du conte à la réalité
# 1112  Pourquoi on aimerait voir un reboot de Darksta...
# 694   Pourquoi on aimerait un retour de la licence d...
#
#                  date_parution  journal_code     journal  \
# 913    28 janvier 2022 à 16:40             1  ActuGaming
# 833        9 mars 2022 à 12:01             1  ActuGaming
# 1765  15 décembre 2021 à 11h35             2        Elle
# 1112    6 février 2022 à 11:00             1  ActuGaming
# 694       20 mars 2022 à 11:00             1  ActuGaming
#
#                                                   texte tranche_nb_origin  \
# 913   Mine de rien, l’année 2021 a été assez chargée...    (3300, 100000]
# 833   Depuis le lancement de la nouvelle trilogie my...      (2100, 2399]
# 1765  Il était une fois une princesse enfermée dans ...      (1800, 2099]
# 1112  Fort des succès critiques et commerciaux de Dr...      (1800, 2099]
# 694   Certains jeux vous marquent à vie, et pas touj...      (2100, 2399]
#
#                                             clean_words  \
# 913   [mine, rien, annee, a, assez, chargee, sorties...
# 833   [depuis, lancement, nouvelle, trilogie, mythol...
# 1765  [fois, princesse, enfermee, etrange, melancoli...
# 1112  [fort, succes, critiques, commerciaux, dragon,...
# 694   [certains, jeux, marquent, vie, toujours, rais...
#
#                                             texte_clean  \
# 913   mine,rien,annee,a,assez,chargee,sorties,gros,m...
# 833   depuis,lancement,nouvelle,trilogie,mythologiqu...
# 1765  fois,princesse,enfermee,etrange,melancolie,pri...
# 1112  fort,succes,critiques,commerciaux,dragon,ball,...
# 694   certains,jeux,marquent,vie,toujours,raisons,fa...
#
#                                          sentence_clean         a  ...  \
# 913   mine rien annee a assez chargee sorties gros m...  0.142739  ...
# 833   depuis lancement nouvelle trilogie mythologiqu...  0.127395  ...
# 1765  fois princesse enfermee etrange melancolie pri...  0.226216  ...
# 1112  fort succes critiques commerciaux dragon ball ...  0.130456  ...
# 694   certains jeux marquent vie toujours raisons fa...  0.098315  ...
#
#          ville  vivant     vivre      voir      vont  vraiment        vu  \
# 913   0.024169     0.0  0.012168  0.029290  0.000000  0.039752  0.020498
# 833   0.000000     0.0  0.000000  0.026795  0.000000  0.000000  0.000000
# 1765  0.000000     0.0  0.000000  0.026433  0.000000  0.035875  0.000000
# 1112  0.000000     0.0  0.000000  0.000000  0.042049  0.037239  0.076808
# 694   0.136506     0.0  0.000000  0.041357  0.031689  0.056129  0.000000
#
#       west  william      xbox
# 913    0.0      0.0  0.044071
# 833    0.0      0.0  0.080633
# 1765   0.0      0.0  0.000000
# 1112   0.0      0.0  0.000000
# 694    0.0      0.0  0.031114
#
# [5 rows x 409 columns]

# %% [markdown]
# <div style="display: flex; background-color: indigo;" >
#
# #### 4.0.3. Préparer le test et train
# </div>

# %%
from sklearn.model_selection import train_test_split

# %%
numeric_cols = get_numeric_columns_names(idf_full, verbose=verbose)
numeric_cols.remove(target_name)
numeric_cols
# Out:
# ['a',
#  'acte',
#  'action',
#  'actrice',
#  'adoption',
#  'affirme',
#  'afin',
#  'age',
#  'agit',
#  'aide',
#  'ailleurs',
#  'ainsi',
#  'alerte',
#  'amis',
#  'amour',
#  'an',
#  'animal',
#  'animale',
#  'animaux',
#  'annee',
#  'annees',
#  'annonce',
#  'ans',
#  'apres',
#  'arrete',
#  'arrivee',
#  'assez',
#  'association',
#  'associations',
#  'aucun',
#  'aucune',
#  'aujourd',
#  'aupres',
#  'autant',
#  'autour',
#  'autres',
#  'avant',
#  'avoir',
#  'beaucoup',
#  'besoin',
#  'biodiversite',
#  'bon',
#  'bonne',
#  'britney',
#  'ca',
#  'car',
#  'cas',
#  'cause',
#  'cela',
#  'celle',
#  'celui',
#  'centre',
#  'certaines',
#  'certains',
#  'cet',
#  'ceux',
#  'chanteuse',
#  'chaque',
#  'charge',
#  'chasse',
#  'chasseurs',
#  'chat',
#  'chats',
#  'chez',
#  'chien',
#  'chienne',
#  'chiens',
#  'chose',
#  'choses',
#  'ci',
#  'cirques',
#  'code',
#  'comment',
#  'compagnie',
#  'compte',
#  'conditions',
#  'confie',
#  'confirme',
#  'contre',
#  'cote',
#  'cotes',
#  'couple',
#  'cours',
#  'cruaute',
#  'cur',
#  'date',
#  'debut',
#  'decembre',
#  'decide',
#  'decision',
#  'declare',
#  'deja',
#  'demande',
#  'depuis',
#  'dernier',
#  'derniere',
#  'desormais',
#  'deux',
#  'devant',
#  'devrait',
#  'dire',
#  'disponible',
#  'dit',
#  'doit',
#  'donne',
#  'dont',
#  'dr',
#  'droit',
#  'durant',
#  'e',
#  'eau',
#  'effet',
#  'egalement',
#  'elevage',
#  'elevages',
#  'elisabeth',
#  'elles',
#  'enfant',
#  'enfants',
#  'enfin',
#  'enquete',
#  'ensemble',
#  'ensuite',
#  'entre',
#  'environnement',
#  'equipe',
#  'espece',
#  'especes',
#  'etat',
#  'europeenne',
#  'euros',
#  'eviter',
#  'exemple',
#  'explique',
#  'face',
#  'faire',
#  'fait',
#  'famille',
#  'faune',
#  'faut',
#  'femme',
#  'ferme',
#  'fevrier',
#  'fille',
#  'film',
#  'fils',
#  'fin',
#  'fois',
#  'fondation',
#  'font',
#  'fr',
#  'francais',
#  'france',
#  'gens',
#  'gouvernement',
#  'grace',
#  'grand',
#  'grande',
#  'groupe',
#  'harry',
#  'heures',
#  'histoire',
#  'homme',
#  'hui',
#  'humains',
#  'hutin',
#  'ici',
#  'ifop',
#  'ii',
#  'images',
#  'initiative',
#  'instagram',
#  'interdiction',
#  'jamais',
#  'janvier',
#  'jeu',
#  'jeune',
#  'jeunes',
#  'jeux',
#  'jour',
#  'jours',
#  'jusqu',
#  'juste',
#  'kanye',
#  'kardashian',
#  'kate',
#  'kim',
#  'laisse',
#  'lannion',
#  'laquelle',
#  'leurs',
#  'lieu',
#  'lire',
#  'loi',
#  'loin',
#  'long',
#  'lors',
#  'lorsqu',
#  'lorsque',
#  'maintenant',
#  'maison',
#  'maitre',
#  'mal',
#  'malgre',
#  'malheureusement',
#  'maltraitance',
#  'maniere',
#  'manque',
#  'mariage',
#  'mars',
#  'meghan',
#  'mere',
#  'mesures',
#  'mettre',
#  'middleton',
#  'mieux',
#  'milieu',
#  'millions',
#  'millionsdamis',
#  'ministre',
#  'mis',
#  'mise',
#  'mode',
#  'moins',
#  'mois',
#  'moment',
#  'monde',
#  'mort',
#  'nationale',
#  'nature',
#  'ndlr',
#  'ni',
#  'noel',
#  'nombre',
#  'nombreuses',
#  'nombreux',
#  'non',
#  'notamment',
#  'nourriture',
#  'nouveau',
#  'nouveaux',
#  'nouvelle',
#  'nouvelles',
#  'novembre',
#  'occasion',
#  'of',
#  'oiseaux',
#  'operation',
#  'or',
#  'parce',
#  'parfois',
#  'paris',
#  'parmi',
#  'part',
#  'partage',
#  'partagee',
#  'partie',
#  'passe',
#  'passer',
#  'pays',
#  'pc',
#  'pendant',
#  'pense',
#  'pere',
#  'periode',
#  'permet',
#  'personne',
#  'personnes',
#  'petit',
#  'petite',
#  'petits',
#  'peu',
#  'peut',
#  'peuvent',
#  'photo',
#  'photos',
#  'place',
#  'plainte',
#  'playstation',
#  'plusieurs',
#  'point',
#  'pompiers',
#  'porte',
#  'possible',
#  'poules',
#  'pourrait',
#  'pourtant',
#  'pouvoir',
#  'pratique',
#  'precise',
#  'premier',
#  'premiere',
#  'prendre',
#  'pres',
#  'presence',
#  'president',
#  'presidente',
#  'prince',
#  'princesse',
#  'pris',
#  'prise',
#  'prix',
#  'prochain',
#  'projet',
#  'protection',
#  'ps',
#  'pu',
#  'public',
#  'publication',
#  'publique',
#  'puis',
#  'puisque',
#  'quand',
#  'quant',
#  'quatre',
#  'quelque',
#  'quelques',
#  'question',
#  'raison',
#  'rapport',
#  'recemment',
#  'recherche',
#  'refuge',
#  'reha',
#  'reine',
#  'relation',
#  'rencontre',
#  'reseaux',
#  'responsable',
#  'reste',
#  'retour',
#  'retrouve',
#  'retrouver',
#  'rien',
#  'risque',
#  'role',
#  'royale',
#  'saint',
#  'sans',
#  'sante',
#  'sauvage',
#  'sauvages',
#  'savoir',
#  'selon',
#  'semaine',
#  'semaines',
#  'semble',
#  'serie',
#  'seul',
#  'seulement',
#  'site',
#  'situation',
#  'sociaux',
#  'soins',
#  'sortie',
#  'sortir',
#  'source',
#  'sous',
#  'souvent',
#  'spears',
#  'star',
#  'studio',
#  'suite',
#  'sujet',
#  'switch',
#  'tant',
#  'tard',
#  'temps',
#  'tete',
#  'the',
#  'titre_y',
#  'toujours',
#  'toute',
#  'toutefois',
#  'toutes',
#  'travail',
#  'travers',
#  'trois',
#  'trop',
#  'trouve',
#  'trouver',
#  'va',
#  'veritable',
#  'vers',
#  'version',
#  'veterinaire',
#  'victimes',
#  'video',
#  'vie',
#  'vient',
#  'ville',
#  'vivant',
#  'vivre',
#  'voir',
#  'vont',
#  'vraiment',
#  'vu',
#  'west',
#  'william',
#  'xbox']

# %%
# On prend uniquement les colonnes qui nous intéresse (identifiée précédemment)
X_train_idf, X_test_idf, y_train_idf, y_test_idf = train_test_split(idf_full[numeric_cols], idf_full[target_name], test_size=0.2, random_state=random_state)
print(f" Train : {X_train_idf.shape} et {y_train_idf.shape} --- Test : {X_test_idf.shape} et {y_test_idf.shape}")
# Out:
#  Train : (1472, 400) et (1472,) --- Test : (368, 400) et (368,)

# %% [markdown]
# <div style="display: flex; background-color: indigo;" >
#
# #### 4.0.4. Prédiction
# </div>

# %%
from sklearn.naive_bayes import GaussianNB, MultinomialNB, ComplementNB,BernoulliNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn.svm import LinearSVC

# %%
verbose = 0

#Create classifier
model_list = {
    "LogisticR":LogisticRegression(random_state=random_state, verbose=verbose),
    "SVC":svm.SVC(random_state=random_state, verbose=verbose), # SCORE de 0.643333
    "KNN":KNeighborsClassifier(n_neighbors=3), # SCRORE de 0.558333
    "LinearSVC":LinearSVC(random_state=random_state, verbose=verbose),
    "naiveGaussianNB":GaussianNB(),
    "MultinomialNB": MultinomialNB(),
    "ComplementNB": ComplementNB(),
    "BernoulliNB":BernoulliNB()
}

# Train the model using the training sets
model_dic_idf, scores_idf = fit_and_test_models(model_list, X_train=X_train_idf, Y_train=y_train_idf, X_test=X_test_idf, Y_test=y_test_idf, verbose=verbose)

score_all_class_df = pd.DataFrame(scores_idf).set_index("Modeli")
score_all_class_df.round(decimals=3)
score_all_class_df = score_all_class_df.sort_values(by="R2", ascending=False)
score_all_class_df
# Out:
#                 Class            Model        R2  fit time  fit seconde
# Modeli
# BernoulliNB                BernoulliNB  0.989130  00:00:00     0.001144
# SVC                                SVC  0.983696  00:00:00     0.222690
# LinearSVC                    LinearSVC  0.980978  00:00:00     0.021677
# LogisticR                    LogisticR  0.978261  00:00:00     0.128786
# naiveGaussianNB        naiveGaussianNB  0.967391  00:00:00     0.019015
# MultinomialNB            MultinomialNB  0.961957  00:00:00     0.007009
# ComplementNB              ComplementNB  0.959239  00:00:00     0.006689
# KNN                                KNN  0.956522  00:00:00     0.026273

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_params_BernoulliNB = { 'alpha' : [0,1],
                            'binarize' : [0.0, 0.5,1],
                            'fit_prior' : [True,False]
                            }

# %%
cross_validation = 3
grid_model_list = {
    "Grid_BernoulliNB":GridSearchCV(estimator=BernoulliNB(), param_grid=grid_params_BernoulliNB, cv=cross_validation, verbose=verbose),
}

# %%
# Train the model using the training sets
model_dic_idf_grid, scores_idf_grid = fit_and_test_models(grid_model_list, X_train=X_train_idf, Y_train=y_train_idf, X_test=X_test_idf, Y_test=y_test_idf, scores=scores_idf, verbose=verbose)

score_grid_idf = pd.DataFrame(scores_idf_grid).set_index("Modeli")
score_grid_idf.round(decimals=3)
score_grid_idf = score_grid_idf.sort_values(by="R2", ascending=False)
score_grid_idf
# Out:
#                  Class             Model        R2  fit time  fit seconde
# Modeli
# BernoulliNB                  BernoulliNB  0.989130  00:00:00     0.001144
# Grid_BernoulliNB        Grid_BernoulliNB  0.989130  00:00:00     0.601882
# SVC                                  SVC  0.983696  00:00:00     0.222690
# LinearSVC                      LinearSVC  0.980978  00:00:00     0.021677
# LogisticR                      LogisticR  0.978261  00:00:00     0.128786
# naiveGaussianNB          naiveGaussianNB  0.967391  00:00:00     0.019015
# MultinomialNB              MultinomialNB  0.961957  00:00:00     0.007009
# ComplementNB                ComplementNB  0.959239  00:00:00     0.006689
# KNN                                  KNN  0.956522  00:00:00     0.026273

# %% [markdown]
# <div style="display: flex; background-color: Green; padding: 7px;" >
#
# ### 4.1.Essaie avec W2V

# %%
from gensim import downloader as g_dwnl
# Out:
# The kernel failed to start as a dll could not be loaded.
#
# Click <a href='https://aka.ms/kernelFailuresDllLoad'>here</a> for more info.

# %%
g_dwnl.info()["models"].keys()
# Out:
# The kernel failed to start as a dll could not be loaded.
#
# Click <a href='https://aka.ms/kernelFailuresDllLoad'>here</a> for more info.

# %%
glove_vectors = g_dwnl.load('glove-wiki-gigaword-100')
# Out:
# The kernel failed to start as a dll could not be loaded.
#
# Click <a href='https://aka.ms/kernelFailuresDllLoad'>here</a> for more info.

# %% [markdown]
# <div style="display: flex; background-color: indigo;" >
#
# #### 4.0.2. Calcul
# </div>

# %% [markdown]
# <div style="display: flex; background-color: indigo;" >
#
# #### 4.0.3. Préparer le test et train
# </div>

# %% [markdown]
# <div style="display: flex; background-color: Green; padding: 7px;" >
#
# ### 4.1.Test de plusieurs modèles
# </div>
#
# *   Entrainer un modèle de classification
# *   Afficher la matrice de confusion
# *   Calculer l'accuracy, la précision et le recall
# *   Votre modèle est-il soumis à un overfitting ?

# %%
from sklearn.naive_bayes import GaussianNB, MultinomialNB, ComplementNB,BernoulliNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn.svm import LinearSVC
# Out:
# The kernel failed to start as a dll could not be loaded.
#
# Click <a href='https://aka.ms/kernelFailuresDllLoad'>here</a> for more info.

# %% [markdown]
# <div style="display: flex; background-color: Green; padding: 7px;" >
#
# ### 4.2.Optimisation du modèle retenu
# </div>

# %% [markdown]
# <div style="display: flex; background-color: Green; padding: 7px;" >
#
# ### 4.3.Sauvegarde du modèle entrainé
# </div>

# %% [markdown]
# <div style="display: flex; background-color: Green; padding: 7px;" >
#
# ### 4.4.Prédiction
# </div>

# %% [markdown]
# <div style="display: flex; background-color: Blue; padding: 15px;" >
#
# ## ANNEXE
# </div>
